# %%
import pandas as pd
import numpy as np
import pickle

df = pickle.load( open( "files/df.pickle", "rb" ) )

print('tweets',df.shape[0])
print('Russian',np.sum(df['Category']))
# Out:
# tweets 8961258
# Russian 2365553

# %%
from sklearn.utils import resample

df_majority = df[df['Category']==0]
df_minority = df[df['Category']==1]
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=df_minority.shape[0]    # to match minority class
                                 ) 

df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# %%
from sklearn.model_selection import train_test_split

X, _, _, _ = train_test_split(df_downsampled['Processed'], df_downsampled['Category'])

cv = pickle.load( open( "models/countVectorizer.pickle", "rb" ) )
X = cv.transform(X)
X.shape
# Out:
# (3548329, 1195)

# %%
import time
from sklearn.decomposition import LatentDirichletAllocation

topics = 50
start = time.time()

model = LatentDirichletAllocation(topics, max_iter=10, n_jobs=4, verbose=3)
model.fit(X)

end = time.time()
print('{} Number of tweets took {:.0f} s'.format(X.shape[0],end-start))
pickle.dump( model, open( "models/lda_model.pickle".format(topics), "wb" ) )
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:  2.7min finished
# iteration: 1 of max_iter: 10
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:  2.4min finished
# iteration: 2 of max_iter: 10
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:  2.0min finished
# iteration: 3 of max_iter: 10
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:  1.9min finished
# iteration: 4 of max_iter: 10
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:  1.8min finished
# iteration: 5 of max_iter: 10
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# ...

# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

_, X, _, y = train_test_split(df[df['Category']==1]['Processed'], df[df['Category']==1]['Category'], train_size=0.9)
X = cv.transform(X)

pyLDAvis.sklearn.prepare(model, X, cv, sort_topics=False)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    6.0s finished
# C:\Users\darin\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.046489 -0.032083       1        1   1.473331
# 1      0.123726 -0.283351       2        1   2.918296
# 2      0.018201  0.038171       3        1   1.338968
# 3      0.042239 -0.027111       4        1   1.829504
# 4      0.100461 -0.168542       5        1   2.594935
# 5      0.029946  0.051059       6        1   1.459951
# ...
